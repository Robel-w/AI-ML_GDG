# %% [markdown]
# <a href="https://colab.research.google.com/github/Robel-w/AI-ML_GDG/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a_list = [1,2,3,4,5]
an_array = np.array(a_list)

mean = np.mean(an_array)
maximum = np.max(an_array)
summ = np.sum(an_array)
print(mean, maximum, summ)
# Out:
# 3.0 5 15
